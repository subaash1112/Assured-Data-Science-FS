# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_excel('https://github.com/subaash1112/Assured-Data-Science-FS/blob/medium_data/sportsdata.xls?raw=true',usecols=['Age'])

# %%
print(df.describe())
# Out:
#                Age
# count  5000.000000
# mean     25.012200
# std       5.013849
# min       4.000000
# 25%      22.000000
# 50%      25.000000
# 75%      28.000000
# max      43.000000

# %%
plt.hist(df['Age'])
# Out:
# (array([1.000e+00, 1.900e+01, 1.160e+02, 5.340e+02, 1.234e+03, 1.578e+03,
#         1.027e+03, 3.880e+02, 9.100e+01, 1.200e+01]),
#  array([ 4. ,  7.9, 11.8, 15.7, 19.6, 23.5, 27.4, 31.3, 35.2, 39.1, 43. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Age'], bins=9)
# Out:
# (array([   2.,   38.,  166.,  981., 1543., 1330.,  783.,  139.,   18.]),
#  array([ 4.        ,  8.33333333, 12.66666667, 17.        , 21.33333333,
#         25.66666667, 30.        , 34.33333333, 38.66666667, 43.        ]),
#  <BarContainer object of 9 artists>)

# %%
plt.hist(df['Age'], bins=[0,5,10,15,20,25,35,40,45,50])
# Out:
# (array([1.000e+00, 5.000e+00, 9.000e+01, 5.740e+02, 1.653e+03, 2.520e+03,
#         1.450e+02, 1.200e+01, 0.000e+00]),
#  array([ 0,  5, 10, 15, 20, 25, 35, 40, 45, 50]),
#  <BarContainer object of 9 artists>)

# %%
plt.hist(df['Age'], bins=[20,25,35,40,45,50])
# Out:
# (array([1653., 2520.,  145.,   12.,    0.]),
#  array([20, 25, 35, 40, 45, 50]),
#  <BarContainer object of 5 artists>)

# %%
plt.hist(df['Age'], bins=range(0,55,5), log=True)
# Out:
# (array([1.000e+00, 5.000e+00, 9.000e+01, 5.740e+02, 1.653e+03, 1.737e+03,
#         7.830e+02, 1.450e+02, 1.200e+01, 0.000e+00]),
#  array([ 0,  5, 10, 15, 20, 25, 30, 35, 40, 45, 50]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df['Age'], bins=9, align='right', color='purple', edgecolor='black')
# Out:
# (array([   2.,   38.,  166.,  981., 1543., 1330.,  783.,  139.,   18.]),
#  array([ 4.        ,  8.33333333, 12.66666667, 17.        , 21.33333333,
#         25.66666667, 30.        , 34.33333333, 38.66666667, 43.        ]),
#  <BarContainer object of 9 artists>)

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %%
df.hist(grid=False, bins=9)
# Out:
# array([[<AxesSubplot:title={'center':'Age'}>]], dtype=object)

# %%
df.hist(grid=False, bins=9)
plt.xlabel('Age of Players')
plt.ylabel('# of Players')
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')

# %%
df.hist(grid=False, bins=range(0,55,5))
plt.xlabel('Age of Players')
plt.ylabel('# of Players')
plt.title('Age Distribution')
# Out:
# Text(0.5, 1.0, 'Age Distribution')
